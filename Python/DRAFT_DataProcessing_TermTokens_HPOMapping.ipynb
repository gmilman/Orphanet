# %% [markdown]
# # Data prep
# the disease definitions consist of two parts, the first part contains the primary disease classification (i.e. what medical speciality does the disease fall into) and the second, the disease description. Only the second part is required for the comparison to the clinical annotations
#
# 0. import nomenclature data
# 1. put everything in lower case
# 2. to split the disease on term 'characterized by'
# 3. keep both parts, classif for different analysis and description for tokenisation

# %%
#import re
import pandas as pd

df=pd.read_csv('processed_data/orpha_nomenclature.csv')

# %%
#convert sentences to lowercase
df['Definition']=df['Definition'].str.lower()

# %%
df.columns
# Out:
# Index(['OrphaCode', 'Name', 'DisorderType', 'ClassificationLevel',
#        'Definition'],
#       dtype='object')

# %%
test='A rare severe, X-linked, neurodevelopmental disorder characterised by rapid developmental regression in infancy, partial or complete loss of purposeful hand movements, loss of speech, gait abnormalities, and stereotypic hand movements, commonly associated with deceleration of head growth, severe intellectual disability, seizures, and breathing abnormalities. The disorder has a progressive clinical course and \
        may associate various comorbidities including gastrointestinal diseases, scoliosis, and behavioral disorders.'

#split_results =re.split(r'characteri(?:zed|sed)+\sby',test)[1]

pattern = r'(.*?)\s*characteri(?:zed|sed)+\s*by\s*(.*)'

df[['ParsedClassification','ParsedDescription']]=df['Definition'].str.extract(pattern).apply(lambda x:x.str.strip())

# %%
#df.drop(labels=['ParsedClassification','ParsedDescription'], axis=1,inplace=True)
display(df['ParsedClassification'][0])

df['ParsedDescription'][0:10]
df.isna().sum()
# Out:
# 'a rare primary bone dysplasia'
# OrphaCode                  0
# Name                       0
# DisorderType               0
# ClassificationLevel        0
# Definition                 0
# ParsedClassification    1261
# ParsedDescription       1261
# dtype: int64

# %%
def_to_check=df[['Definition','ClassificationLevel']].loc[df['ParsedClassification'].isna()]
def_to_check.to_csv('processed_data\def_to_check.csv')

# %% [markdown]
# Trying to split on several different patterns, but proving difficult, COME BACK TO
# from trying three patterns gives back 600 results, which is 2/3 of the definitions at disorder level

# %%
def_to_check['ClassificationLevel'].value_counts()
# in general need to drop group of disorders and subtype of disorder
# from looking at the left over definitions we need to include the following terms in the extractions

pattern1 = r'(.*?)\s*manifest(?:s|ing)\s*(.*)'
pattern2 = r'(.*?)\s*present(?:s|ing)\s*(.*)'
pattern3= r'(.*?)\s*characterized\s*(.*)'

def_to_check[['ParsedClassification','ParsedDescription']]=def_to_check['Definition'].str.extract(pattern3).apply(lambda x:x.str.strip())
def_to_check.notna().sum()
# Out:
# Definition              1261
# ClassificationLevel     1261
# ParsedClassification     209
# ParsedDescription        209
# dtype: int64

# %%
[(.*?)\s*manifest(?:s|ing)\s*(.*)']
[(.*?)\s*present(?:s|ing)\s*(.*)']
 [(.*?)\s*characterized\s*(.*)']

# %% [markdown]
# # Entity recognition
# so far not worked with pre-trained models - they require more training
# thus looking at ranking with fuzzy wuzzy

# %%
import fuzzywuzzy
import re
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from pywsd.utils import lemmatize_sentence
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gemma\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\gemma\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\gemma\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\gemma\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %%
display(df.shape)
df.head()
# Out:
# (8527, 7)
#    OrphaCode                                               Name DisorderType  \
# 0     166024      Multiple epiphyseal dysplasia, Al-Gazali type      Disease
# 1         58                                  Alexander disease      Disease
# 2     166032  Multiple epiphyseal dysplasia, with miniepiphyses      Disease
# 3         61                                 Alpha-mannosidosis      Disease
# 4     166029  Multiple epiphyseal dysplasia, with severe pro...      Disease
#
#   ClassificationLevel                                         Definition  \
# 0            Disorder  a rare primary bone dysplasia characterized by...
# 1            Disorder  a rare neurodegenerative disorder of the astro...
# 2            Disorder  multiple epiphyseal dysplasia, with miniepiphy...
# 3            Disorder  an inherited lysosomal storage disorder charac...
# 4            Disorder  multiple epiphyseal dysplasia, with severe pro...
#
#                                 ParsedClassification  \
# 0                      a rare primary bone dysplasia
# 1                                                NaN
# 2  multiple epiphyseal dysplasia, with miniepiphy...
# 3            an inherited lysosomal storage disorder
# 4  multiple epiphyseal dysplasia, with severe pro...
#
#                                    ParsedDescription
# 0  the association of multiple epiphyseal dysplas...
# 1                                                NaN
# 2  strikingly small secondary ossification center...
# 3  immune deficiency, facial and skeletal abnorma...
# 4  severe, early-onset dysplasia of the proximal ...

# %%
len(df['ParsedDescription'].loc[df['ParsedClassification'].notna()])
## extract codes and description for the disorder level entities
orpha_description_disorder_level= df['ParsedDescription'].loc[(df['ParsedClassification'].notna())& (df['ClassificationLevel']=='Disorder')]
orpha_codes_disorder_level= df['OrphaCode'].loc[(df['ParsedClassification'].notna())& (df['ClassificationLevel']=='Disorder')]

# check lengths of each column extracted:
display(len(orpha_codes_disorder_level))
len(orpha_description_disorder_level)
# Out:
# 5884
# 5884

# %%
# Out:
# 5954
# 5954

# %%
#Function:split the defintion strings into clinical components
#input: the column for the orpha codes and the column containing the disease definition
#output: dictionary containing the orpha codes (keys) with a list of the extracted terms for that orpha code

def extract_clinical_terms(df_codes,df_text):

    stop_words=list(STOP_WORDS)

    token_split=[]
    token_clean=[]
    token_list_clean=[]
    orpha_tokens={}

    lmtzr = WordNetLemmatizer()

    #look at adding (onset, reported, neonatal != neonatal hypotonia, juvenile, adult, manifest ing ation \s) to the pattern

    for orpha, row in zip(df_codes,df_text):
        pattern=', |\s+and+\s|includ(?:es|e|ing)|associat(?:es|ed|e|ing)|\.|show(?:s|ing)|marked|resulting|\s+or+\s|present(?:\s|s|ing)|with onset|such as|linked to|combined with|with worsening|with\s'
        row= re.sub(r'\([^)]*\)', '',row) # remove text in parenthesis as not needed
        token_list=re.split(pattern, row)
        # strip
        token_list=[token.strip() for token in token_list]

        #remove stop words and lemmatize terms to improve search and mathcing later
        lemmatized = [[lmtzr.lemmatize(word) for word in word_tokenize(w) if word not in stop_words]
                  for w in token_list]
        token_clean=[' '.join(lem) for lem in lemmatized]
        #removing empty string elements from list
        token_clean = [ele for ele in token_clean if ele.strip()]
        token_list_clean.append(token_clean)

        #dictionary of orpha code with corresponding list of clinical phenotypes
        orpha_tokens[orpha]=token_clean
    return orpha_tokens
    
orpha_terms=extract_clinical_terms(orpha_codes_disorder_level,orpha_description_disorder_level)

# %%
#Function:split the defintion strings into clinical components
#input: the column for the orpha codes and the column containing the disease definition
#output: dictionary containing the orpha codes (keys) with a list of the extracted terms for that orpha code

# without lemmatizer to see if affects results
def extract_clinical_terms(df_codes,df_text,file_name):
    import pickle

    
    stop_words=list(STOP_WORDS)

    token_split=[]
    token_clean=[]
    token_list_clean=[]
    orpha_tokens={}

    lmtzr = WordNetLemmatizer()

    #look at adding (onset, reported, neonatal != neonatal hypotonia, juvenile, adult, manifest ing ation \s) to the pattern

    for orpha, row in zip(df_codes,df_text):
        pattern=', |\s+and+\s|includ(?:es|e|ing)|associat(?:es|ed|e|ing)|\.|show(?:s|ing)|marked|resulting|\s+or+\s|present(?:\s|s|ing)|with onset|such as|linked to|combined with|with worsening|with\s'
        row= re.sub(r'\([^)]*\)', '',row) # remove text in parenthesis as not needed
        token_list=re.split(pattern, row)
        # strip
        token_list=[token.strip() for token in token_list]

        #remove stop words and lemmatize terms to improve search and mathcing later
        remove_stop = [[word for word in word_tokenize(w) if word not in stop_words]
                  for w in token_list]
        token_clean=[' '.join(lem) for lem in remove_stop]
        #removing empty string elements from list
        token_clean = [ele for ele in token_clean if ele.strip()]
        token_list_clean.append(token_clean)

        #dictionary of orpha code with corresponding list of clinical phenotypes
        orpha_tokens[orpha]=token_clean
        with open(f'processed_data/{file_name}.pickle', 'wb') as f:
            pickle.dump(orpha_tokens,f)
    return orpha_tokens
    
orpha_terms=extract_clinical_terms(df['OrphaCode'].loc[df['ParsedClassification'].notna()],df['ParsedDescription'].loc[df['ParsedClassification'].notna()],'orpha_ner')

# %%
def replace_html_entities(match):
    import html
    import html.entities
    entity = match.group(0)
    if entity in html.entities.html5:
        return chr(html.entities.html5[entity])
    else:
        return entity

# Decode the HTML-encoded text in the dictionary
decoded_orpha_terms = {}
for key, value in orpha_terms.items():
    if isinstance(key, (str, bytes)):
        decoded_key = html.unescape(re.sub(r'&[a-zA-Z0-9#]+;', replace_html_entities, key))
    else:
        decoded_key = key

    if isinstance(value, str):
        decoded_value = html.unescape(re.sub(r'&[a-zA-Z0-9#]+;', replace_html_entities, value))
    else:
        decoded_value = value

    decoded_orpha_terms[decoded_key] = decoded_value

# Now the 'decoded_terms' dictionary contains the decoded data
#print(decoded_terms)



display(len(decoded_orpha_terms))
display(len(orpha_terms))
list(decoded_orpha_terms.items())[0:10]
# Out:
# 5884
# 5884
# [(166024,
#   ['association multiple epiphyseal dysplasia',
#    'macrocephaly',
#    'dysmorphic facial feature',
#    'patient normal stature',
#    'joint swelling',
#    'genu valgum',
#    'additional reported manifestation',
#    'clinodactyly',
#    'spindle-shaped finger',
#    'pectus excavatum']),
#  (166032,
#   ['strikingly small secondary ossification center',
#    'joint',
#    'severe bone dysplasia proximal femoral head',
#    'short stature',
#    'increased lumbar lordosis',
#    'genu vara',
#    'generalized joint laxity reported']),
#  (61,
#   ['immune deficiency',
#    'facial',
#    'skeletal abnormality',
#    'hearing impairment',
#    'intellectual deficit']),
#  (166029,
#   ['severe',
#    'early-onset dysplasia proximal femur',
#    'complete absence secondary ossification center',
#    'abnormal development femoral neck',
#    'gait abnormality',
#    'mild short stature',
#    'arthralgia',
#    'joint stiffness',
#    'limited mobility hip',
#    'irregular acetabulum',
#    'hip',
#    'knee pain',
#    'coxa vara',
#    'mild spinal change']),
#  (166038,
#   ['disproportionate short stature',
#    'short limb',
#    'digit',
#    'tracheobronchial malacia',
#    'progressive thoracolumbar scoliosis',
#    'radiographic imaging',
#    'progression',
#    'metaphyseal dysplasia tubular bone childhood short',
#    'broad bone',
#    'mild dysplasia joint adulthood',
#    'description literature 1982']),
#  (166035,
#   ['mild severe short stature',
#    'brachydactyly',
#    'retinal degeneration',
#    'variable intellectual disability',
#    'developmental delay',
#    'craniofacial anomaly']),
#  (585,
#   ['clinical phenotype combine feature different sulfatase deficiency neonatal',
#    'infantile',
#    'juvenile presentation',
#    'manifestation',
#    'hypotonia',
#    'coarse facial feature',
#    'mild deafness',
#    'skeletal anomaly',
#    'ichthyosis',
#    'hepatomegaly',
#    'developmental delay',
#    'progressive neurologic deterioration',
#    'hydrocephalus']),
#  (118,
#   ['developmental delay varying severity',
#    'hearing loss',
#    'manifest wide phenotypic heterogeneity']),
#  (166068,
#   ['developmental delay varying severity',
#    'hearing loss',
#    'manifest wide phenotypic heterogeneity']),
#  (141, ['mild developmental delay'])]

# %% [markdown]
# # HPO comparison

# %%
df_hpo=pd.read_csv('processed_data\HPO.csv')

# %%
df_hpo.columns
# Out:
# Index(['Unnamed: 0', 'Term', 'ID', 'Definition', 'Synonyms', 'HPO_ID'], dtype='object')

# %%
# put all in lower case and remove commas and dash
# convert terms to list, so that fuzzy can iterate over it
#df_hpo.drop(index=df.index[0], axis=0, inplace=True)
df_hpo['Term']=df_hpo['Term'].str.lower().replace(',','').replace('-','')
hpo_list=df_hpo['Term'].to_list()
hpo_list.sort()
type(orpha_terms)
# Out:
# dict

# %%
# FOR TESTING PRUPOSES ONLY
# create a small test dictionary
# Python code to convert into dictionary
def Convert(tup, di):
    di = dict(tup)
    return di
     
# Driver Code
tups = list(decoded_orpha_terms.items())[0:100]
dictionary = {}
dictionary=Convert(tups, dictionary)

# %%
#Function:Matching of extracted Orphanet terms to the HPO terms 
#Input 1: dictionary of extracted orphanet terms, key= orphacode, values= list of extracted terms
#Input 2: list of HPO terms for matching
#output 1: dictionary of the HPO matched terms, key = orphacode, value = list of HPO terms that have been matched
#Output 2: print of number of input terms and number of matches, where the ratio is above 90

def match_HPO_to_extracted_terms(dictionary, hpo_list):
    from fuzzywuzzy import fuzz
    from fuzzywuzzy import process
    import logging
    import pickle
    
    logging.basicConfig(filename='fuzzy_hpo_match.log', encoding='utf-8', level=logging.INFO,\
                       format='%(asctime)s:%(name)s:%(message)s')

    word_count=0
    match_count=0
    orpha_count=0
    returned_terms={}



    for orpha, disease in dictionary.items():
        HPO_list=[]
        orpha_count+=1
        for word in disease:
            word_count+=1
            hpo_match=process.extract(word, hpo_list, scorer=fuzz.ratio, limit=1)
            #
            if hpo_match[0][1]>90:
                match_count+=1
                logging.info('{} : {} : {}, orpha count= {}, word count = {}, match count= {}'\
                             .format(orpha,word,hpo_match, orpha_count, word_count, match_count))
                HPO_list.append(hpo_match[0][0])
        if len(HPO_list)==0:
                HPO_list.append(None)
        returned_terms[orpha]=HPO_list

    print(f'{match_count} hpo matchess were found out of {word_count} total input terms')
    

    with open ('extracted_HPO_terms_ratio.pickle', 'wb') as f:
        pickle.dump(returned_terms,f)

    return returned_terms
result=match_HPO_to_extracted_terms(decoded_orpha_terms,hpo_list)
# Out:
# 12015 hpo matchess were found out of 53618 total input terms

# %%
#Function:Matching of extracted Orphanet terms to the HPO terms 
#Input 1: dictionary of extracted orphanet terms, key= orphacode, values= list of extracted terms
#Input 2: list of HPO terms for matching
#output 1: dictionary of the HPO matched terms, key = orphacode, value = list of HPO terms that have been matched
#Output 2: print of number of input terms and number of matches, where the ratio is above 90

def match_HPO_to_extracted_terms_all(dictionary, hpo_list):
    from fuzzywuzzy import fuzz
    from fuzzywuzzy import process
    import logging
    import pickle
    
    logging.basicConfig(filename='fuzzy_hpo_match_all.log', encoding='utf-8', level=logging.INFO,\
                       format='%(asctime)s:%(name)s:%(message)s')

    word_count=0
    match_count=0
    orpha_count=0
    returned_terms={}



    for orpha, disease in dictionary.items():
        HPO_list=[]
        orpha_count+=1
        for word in disease:
            word_count+=1
            hpo_match=process.extract(word, hpo_list, limit=1)
            #
            if hpo_match[0][1]>90:
                match_count+=1
                logging.info('{} : {} : {}, orpha count= {}, word count = {}, match count= {}'\
                             .format(orpha,word,hpo_match, orpha_count, word_count, match_count))
                HPO_list.append(hpo_match[0][0])
        if len(HPO_list)==0:
                HPO_list.append(None)
        returned_terms[orpha]=HPO_list

    print(f'{match_count} hpo matchess were found out of {word_count} total input terms')
    

    with open ('extracted_HPO_terms_all.pickle', 'wb') as f:
        pickle.dump(returned_terms,f)

    return returned_terms
result_all=match_HPO_to_extracted_terms_all(decoded_orpha_terms,hpo_list)
# Out:
# 14701 hpo matchess were found out of 53618 total input terms

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4292\1306264091.py in <module>
# ----> 1 type(result)
#
# NameError: name 'result' is not defined

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

word_count=0
match_count=0

for disease in terms_to_compare[1:10]:

    for word in disease:
        word_count+=1
        hpo_match=process.extract(word, hpo_list, scorer = fuzz.ratio, limit=1)
        if hpo_match[0][1]>90:
            match_count+=1
            print(word, ': ',process.extract(word, hpo_list, scorer = fuzz.ratio, limit=1))
print(f'{match_count} hpo matchess were found out of {word_count} total input terms')

# consider getting rid of modifiers from the HPO terminology

#for now i might just go with 100 or 95 cut off, and then work on improving the matching for the model
        
    # immune deficiency not great, hip 55, id 79, hyptonia 100 not bad
# Out:
# short stature :  [('short stature', 100)]
# immune deficiency :  [('immunodeficiency', 91)]
# hearing impairment :  [('hearing impairment', 100)]
# severe :  [('severe', 100)]
# mild short stature :  [('mild short stature', 100)]
# arthralgia :  [('arthralgia', 100)]
# joint stiffness :  [('joint stiffness', 100)]
# knee pain :  [('knee pain', 100)]
# coxa vara :  [('coxa vara', 100)]
# disproportionate short stature :  [('disproportionate short stature', 100)]
# brachydactyly :  [('brachydactyly', 100)]
# retinal degeneration :  [('retinal degeneration', 100)]
# hypotonia :  [('hypotonia', 100)]
# coarse facial features :  [('coarse facial features', 100)]
# ichthyosis :  [('ichthyosis', 100)]
# hepatomegaly :  [('hepatomegaly', 100)]
# progressive neurologic deterioration :  [('progressive neurologic deterioration', 100)]
# hydrocephalus :  [('hydrocephalus', 100)]
# 18 hpo matchess were found out of 63 total input terms

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

word_count=0
match_count=0

for disease in terms_to_compare[1:10]:

    for word in disease:
        word_count+=1
        hpo_match=process.extract(word, hpo_list, scorer = fuzz.token_set_ratio, limit=1)
        if hpo_match[0][1]>90:
            match_count+=1
            print(word, ': ',process.extract(word, hpo_list, scorer = fuzz.token_set_ratio, limit=1))
print(f'{match_count} hpo matchess were found out of {word_count} total input terms')

# consider getting rid of modifiers from the HPO terminology

#for now i might just go with 100 or 95 cut off, and then work on improving the matching for the model
        
    # immune deficiency not great, hip 55, id 79, hyptonia 100 not bad
# Out:
# joints :  [('abnormality of the radioulnar joints', 100)]
# severe bone dysplasia proximal femoral heads :  [('proximal', 100)]
# short stature :  [('asymmetric short stature', 100)]
# generalized joint laxity reported :  [('generalized', 100)]
# facial :  [('abnormal facial artery morphology', 100)]
# hearing impairment :  [('adult onset sensorineural hearing impairment', 100)]
# severe :  [('intellectual disability, severe', 100)]
# early-onset dysplasia proximal femurs :  [('onset', 100)]
# mild short stature :  [('mild', 100)]
# arthralgia :  [('arthralgia', 100)]
# joint stiffness :  [('joint stiffness', 100)]
# hip :  [('abnormal hip bone morphology', 100)]
# knee pain :  [('knee pain', 100)]
# coxa vara :  [('coxa vara', 100)]
# mild spinal changes :  [('mild', 100)]
# disproportionate short stature :  [('disproportionate short stature', 100)]
# short limbs :  [('short lower limbs', 100)]
# digits :  [('autoamputation of digits', 100)]
# progressive thoracolumbar scoliosis :  [('progressive', 100)]
# progression :  [('pace of progression', 100)]
# metaphyseal dysplasia tubular bones childhood short :  [('metaphyseal dysplasia', 100)]
# broad bones :  [('broad carpal bones', 100)]
# mild dysplasia joints adulthood :  [('mild', 100)]
# mild severe short stature :  [('mild', 100)]
# brachydactyly :  [('brachydactyly', 100)]
# retinal degeneration :  [('lattice retinal degeneration', 100)]
# variable intellectual disability :  [('intellectual disability', 100)]
# infantile :  [('acute infantile spinal muscular atrophy', 100)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\fuzzywuzzy\process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     107         # See if choices is a dictionary-like object.
# --> 108         for key, choice in choices.items():
#     109             processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35556\1335538010.py in <module>
#       9     for word in disease:
#      10         word_count+=1
# ---> 11         hpo_match=process.extract(word, hpo_list, scorer = fuzz.token_set_ratio, limit=1)
#      12         if hpo_match[0][1]>90:
#      13             match_count+=1
#
# ~\anaconda3\lib\site-packages\fuzzywuzzy\process.py in extract(query, choices, processor, scorer, limit)
#     166     """
#     167     sl = extractWithoutOrder(query, choices, processor, scorer)
# --> 168     return heapq.nlargest(limit, sl, key=lambda i: i[1]) if limit is not None else \
#     169         sorted(sl, key=lambda i: i[1], reverse=True)
#     170
#
# ~\anaconda3\lib\heapq.py in nlargest(n, iterable, key)
#     529         it = iter(iterable)
#     530         sentinel = object()
# --> 531         result = max(it, default=sentinel, key=key)
#     532         return [] if result is sentinel else [result]
#     533
#
# ~\anaconda3\lib\site-packages\fuzzywuzzy\process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     114         # It's a list; just iterate over it.
#     115         for choice in choices:
# --> 116             processed = pre_processor(processor(choice))
#     117             score = scorer(processed_query, processed)
#     118             if score >= score_cutoff:
#
# ~\anaconda3\lib\site-packages\fuzzywuzzy\utils.py in full_process(s, force_ascii)
#      93         s = asciidammit(s)
#      94     # Keep only Letters and Numbers (see Unicode docs).
# ---> 95     string_out = StringProcessor.replace_non_letters_non_numbers_with_whitespace(s)
#      96     # Force into lowercase.
#      97     string_out = StringProcessor.to_lower_case(string_out)
#
# KeyboardInterrupt:

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

word_count=0
match_count=0

for disease in terms_to_compare[1:10]:

    for word in disease:
        word_count+=1
        hpo_match=process.extract(word, hpo_list, limit=1)
        if hpo_match[0][1]>90:
            match_count+=1
            print(word, ': ',process.extract(word, hpo_list, limit=1))
print(f'{match_count} hpo matchess were found out of {word_count} total input terms')

# consider getting rid of modifiers from the HPO terminology

#for now i might just go with 100 or 95 cut off, and then work on improving the matching for the model
        
    # immune deficiency not great, hip 55, id 79, hyptonia 100 not bad
# Out:
# short stature :  [('short stature', 100)]
# generalized joint laxity reported :  [('generalized joint laxity', 95)]
# immune deficiency :  [('immunodeficiency', 91)]
# hearing impairment :  [('hearing impairment', 100)]
# severe :  [('severe', 100)]
# mild short stature :  [('mild short stature', 100)]
# arthralgia :  [('arthralgia', 100)]
# joint stiffness :  [('joint stiffness', 100)]
# knee pain :  [('knee pain', 100)]
# coxa vara :  [('coxa vara', 100)]
# disproportionate short stature :  [('disproportionate short stature', 100)]
# broad bones :  [('broad long bones', 95)]
# mild severe short stature :  [('mild short stature', 95)]
# brachydactyly :  [('brachydactyly', 100)]
# retinal degeneration :  [('retinal degeneration', 100)]
# variable intellectual disability :  [('intellectual disability', 95)]
# hypotonia :  [('hypotonia', 100)]
# coarse facial features :  [('coarse facial features', 100)]
# ichthyosis :  [('ichthyosis', 100)]
# hepatomegaly :  [('hepatomegaly', 100)]
# developmental delay :  [('global developmental delay', 95)]
# progressive neurologic deterioration :  [('progressive neurologic deterioration', 100)]
# hydrocephalus :  [('hydrocephalus', 100)]
# mild developmental delay :  [('mild global developmental delay', 95)]
# 24 hpo matchess were found out of 63 total input terms

# %%
for disease in terms_to_compare[1:10]:
    for word in disease:
        print(word, ': ',process.extract(word, hpo_list, scorer = fuzz.partial_ratio, limit=1))
        
        #not this one, look at hip 100
# Out:
# strikingly small secondary ossification centers :  [('large sternal ossification centers', 79)]
# joints :  [('abnormality of the radioulnar joints', 100)]
# severe bone dysplasia proximal femoral heads :  [('proximal', 100)]
# short stature :  [('asymmetric short stature', 100)]
# increased lumbar lordosis :  [('increased dlco', 79)]
# genua vara :  [('genu varum', 80)]
# generalized joint laxity reported :  [('generalized', 100)]
# immune deficiency :  [('cellular immunodeficiency', 91)]
# facial :  [('abnormal facial artery morphology', 100)]
# skeletal abnormalities :  [('multiple skeletal anomalies', 90)]
# hearing impairment :  [('adult onset sensorineural hearing impairment', 100)]
# intellectual deficit :  [('intellectual disability', 80)]
# severe :  [('intellectual disability, severe', 100)]
# early-onset dysplasia proximal femurs :  [('onset', 100)]
# complete absence secondary ossification centers :  [('fused sternal ossification centers', 79)]
# abnormal development femoral necks :  [('abnormal ekg', 83)]
# gait abnormality :  [('biliary tract abnormality', 88)]
# mild short stature :  [('mild', 100)]
# arthralgia :  [('arthralgia', 100)]
# joint stiffness :  [('joint stiffness', 100)]
# limited mobility hips :  [('limited mobility of proximal interphalangeal joint', 86)]
# irregular acetabula :  [('irregular acetabular roof', 100)]
# hip :  [('abnormal hip bone morphology', 100)]
# knee pain :  [('knee pain', 100)]
# coxa vara :  [('coxa vara', 100)]
# mild spinal changes :  [('mild', 100)]
# disproportionate short stature :  [('disproportionate short stature', 100)]
# short limbs :  [('childhood onset short-limb short stature', 91)]
# digits :  [('autoamputation of digits', 100)]
# tracheobronchial malacia :  [('cartilaginous tracheobronchomalacia', 89)]
# progressive thoracolumbar scoliosis :  [('lumbar scoliosis', 100)]
# radiographic imaging :  [('pain', 75)]
# progression :  [('pace of progression', 100)]
# metaphyseal dysplasia tubular bones childhood short :  [('metaphyseal dysplasia', 100)]
# broad bones :  [('broad neck', 80)]
# mild dysplasia joints adulthood :  [('mild', 100)]
# descriptions literature 1982 :  [('lateral', 71)]
# mild severe short stature :  [('mild', 100)]
# brachydactyly :  [('brachydactyly', 100)]
# retinal degeneration :  [('chorioretinal degeneration', 100)]
# variable intellectual disability :  [('intellectual disability', 100)]
# developmental delays :  [('global developmental delay', 97)]
# craniofacial anomalies :  [('craniofacial teratoma', 81)]
# clinical phenotype combines features different sulfatase deficiencies neonatal :  [('bone fracture', 77)]
# infantile :  [('acute infantile spinal muscular atrophy', 100)]
# juvenile presentations :  [('breech presentation', 79)]
# manifestations :  [('dermatological manifestations of systemic disorders', 100)]
# hypotonia :  [('appendicular hypotonia', 100)]
# coarse facial features :  [('coarse facial features', 100)]
# mild deafness :  [('mild', 100)]
# skeletal anomalies :  [('multiple skeletal anomalies', 100)]
# ichthyosis :  [('generalized ichthyosis', 100)]
# hepatomegaly :  [('fluctuating hepatomegaly', 100)]
# developmental delay :  [('global developmental delay', 100)]
# progressive neurologic deterioration :  [('progressive', 100)]
# hydrocephalus :  [('communicating hydrocephalus', 100)]
# developmental delay varying severity :  [('severity', 100)]
# hearing loss :  [('aminoglycoside-induced hearing loss', 100)]
# manifest wide phenotypic heterogeneity :  [('mania', 80)]
# developmental delay varying severity :  [('severity', 100)]
# hearing loss :  [('aminoglycoside-induced hearing loss', 100)]
# manifest wide phenotypic heterogeneity :  [('mania', 80)]
# mild developmental delay :  [('mild', 100)]

# %%
for disease in terms_to_compare[1:10]:
    for word in disease:
        print(word, ': ',process.extract(word, hpo_list, scorer = fuzz.ratio, limit=2))
        
        # better hip give 55 and gives immunodeficiency for immune deficiency, intellectual disability fairly good, 79
# Out:
# strikingly small secondary ossification centers :  [('large sternal ossification centers', 69), ('fused sternal ossification centers', 67)]
# joints :  [('colitis', 62), ('joint crepitus', 60)]
# severe bone dysplasia proximal femoral heads :  [('dysplasia of the femoral head', 66), ('aplasia of the femoral head', 59)]
# short stature :  [('short stature', 100), ('mild short stature', 84)]
# increased lumbar lordosis :  [('increased male libido', 70), ('increased urinary orosomucoid', 70)]
# genua vara :  [('genu varum', 80), ('genu valgum', 67)]
# generalized joint laxity reported :  [('generalized joint laxity', 84), ('generalized tonic seizure', 66)]
# immune deficiency :  [('immunodeficiency', 91), ('complement deficiency', 74)]
# facial :  [('acral', 73), ('axial', 73)]
# skeletal abnormalities :  [('multiple skeletal anomalies', 73), ('rib segmentation abnormalities', 73)]
# hearing impairment :  [('hearing impairment', 100), ('mild hearing impairment', 88)]
# intellectual deficit :  [('intellectual disability', 79), ('intellectual disability, mild', 69)]
# severe :  [('severe', 100), ('fever', 73)]
# early-onset dysplasia proximal femurs :  [('club-shaped proximal femur', 63), ('hypoplasia of proximal fibula', 61)]
# complete absence secondary ossification centers :  [('large sternal ossification centers', 72), ('multiple carpal ossification centers', 70)]
# abnormal development femoral necks :  [('abnormal lung development', 68), ('abnormal pigmentation of the oral mucosa', 65)]
# gait abnormality :  [('eeg abnormality', 84), ('emg abnormality', 84)]
# mild short stature :  [('mild short stature', 100), ('short stature', 84)]
# arthralgia :  [('arthralgia', 100), ('anarthria', 74)]
# joint stiffness :  [('joint stiffness', 100), ('aortic stiffness', 77)]
# limited mobility hips :  [('impaired ability to plan', 62), ('limitation of knee mobility', 62)]
# irregular acetabula :  [('irregular acetabular roof', 86), ('irregular patellae', 76)]
# hip :  [('hip pain', 55), ('sharp', 50)]
# knee pain :  [('knee pain', 100), ('bone pain', 78)]
# coxa vara :  [('coxa vara', 100), ('coxa valga', 84)]
# mild spinal changes :  [('personality changes', 63), ('cervical spinal canal stenosis', 61)]
# disproportionate short stature :  [('disproportionate short stature', 100), ('proportionate short stature', 95)]
# short limbs :  [('short ribs', 86), ('short lower limbs', 79)]
# digits :  [('diskitis', 71), ('iritis', 67)]
# tracheobronchial malacia :  [('tracheobronchomalacia', 89), ('tracheobronchmegaly', 74)]
# progressive thoracolumbar scoliosis :  [('thoracolumbar scoliosis', 79), ('progressive congenital scoliosis', 75)]
# radiographic imaging :  [('dermatographic urticaria', 64), ('mass on thoracic imaging', 64)]
# progression :  [('progressive', 82), ('depression', 76)]
# metaphyseal dysplasia tubular bones childhood short :  [('metaphyseal dysplasia', 58), ('epiphyseal deformities of tubular bones', 56)]
# broad bones :  [('broad long bones', 81), ('broad toe', 80)]
# mild dysplasia joints adulthood :  [('death in adulthood', 61), ('death in late adulthood', 59)]
# descriptions literature 1982 :  [('disproportionate tall stature', 56), ('disproportionate short stature', 55)]
# mild severe short stature :  [('severe short stature', 89), ('mild short stature', 84)]
# brachydactyly :  [('brachydactyly', 100), ('arachnodactyly', 81)]
# retinal degeneration :  [('retinal degeneration', 100), ('chorioretinal degeneration', 87)]
# variable intellectual disability :  [('intellectual disability', 84), ('intellectual disability, mild', 75)]
# developmental delays :  [('neurodevelopmental delay', 86), ('global developmental delay', 83)]
# craniofacial anomalies :  [('craniofacial teratoma', 79), ('craniofacial asymmetry', 73)]
# clinical phenotype combines features different sulfatase deficiencies neonatal :  [('abnormal iduronate sulfatase concentration', 47), ('focal autonomic seizure with urge to urinate/defecate', 47)]
# infantile :  [('infantile onset', 75), ('infantile spasms', 72)]
# juvenile presentations :  [('breech presentation', 73), ('ventricular preexcitation', 68)]
# manifestations :  [('agitation', 70), ('palpitations', 69)]
# hypotonia :  [('hypotonia', 100), ('hypertonia', 84)]
# coarse facial features :  [('coarse facial features', 100), ('sparse facial hair', 70)]
# mild deafness :  [('unilateral deafness', 69), ('muscle weakness', 64)]
# skeletal anomalies :  [('multiple skeletal anomalies', 80), ('fetal anomaly', 71)]
# ichthyosis :  [('ichthyosis', 100), ('ecchymosis', 70)]
# hepatomegaly :  [('hepatomegaly', 100), ('hepatosplenomegaly', 80)]
# developmental delay :  [('neurodevelopmental delay', 88), ('global developmental delay', 84)]
# progressive neurologic deterioration :  [('progressive neurologic deterioration', 100), ('progressive language deterioration', 83)]
# hydrocephalus :  [('hydrocephalus', 100), ('severe hydrocephalus', 79)]
# developmental delay varying severity :  [('neurodevelopmental delay', 63), ('developmental cataract', 62)]
# hearing loss :  [('weight loss', 70), ('hemimacroglossia', 64)]
# manifest wide phenotypic heterogeneity :  [('increased hepatic echogenicity', 56), ('decreased hepatic echogenicity', 53)]
# developmental delay varying severity :  [('neurodevelopmental delay', 63), ('developmental cataract', 62)]
# hearing loss :  [('weight loss', 70), ('hemimacroglossia', 64)]
# manifest wide phenotypic heterogeneity :  [('increased hepatic echogenicity', 56), ('decreased hepatic echogenicity', 53)]
# mild developmental delay :  [('mild global developmental delay', 87), ('global developmental delay', 84)]

# %%
for disease in terms_to_compare[1:10]:
    for word in disease:
        print(word, ': ',process.extract(word, hpo_list, scorer = fuzz.token_set_ratio, limit=2))
        
        #immune deficiency way off, hip way off and hypotonia
# Out:
# strikingly small secondary ossification center :  [('Ectopic ossification', 75), ('Fused sternal ossification centers', 72)]
# joint :  [('Abnormal hip joint morphology', 100), ('Abnormal joint morphology', 100)]
# severe bone dysplasia proximal femoral head :  [('Proximal', 100), ('Severe', 100)]
# short stature :  [('Asymmetric short stature', 100), ('Childhood onset short-limb short stature', 100)]
# increased lumbar lordosis :  [('Increased KCO', 82), ('Increased DLCO', 78)]
# genu vara :  [('Genu varum', 84), ('Genu valgum', 70)]
# generalized joint laxity reported :  [('Generalized', 100), ('Generalized joint laxity', 100)]
# immune deficiency :  [('Adrenocorticotropic hormone deficiency', 74), ('Aldehyde oxidase deficiency', 74)]
# facial :  [('Abnormal facial artery morphology', 100), ('Abnormal facial expression', 100)]
# skeletal abnormality :  [('Abnormality of skeletal maturation', 100), ('Abnormality of skeletal muscle fiber size', 100)]
# hearing impairment :  [('Adult onset sensorineural hearing impairment', 100), ('Bilateral conductive hearing impairment', 100)]
# intellectual deficit :  [('Intellectual disability', 79), ('Intellectual disability, borderline', 75)]
# severe :  [('Intellectual disability, severe', 100), ('Severe', 100)]
# early-onset dysplasia proximal femur :  [('Onset', 100), ('Proximal', 100)]
# complete absence secondary ossification center :  [('Ectopic ossification', 75), ('Complete left sided absence of pericardium', 68)]
# abnormal development femoral neck :  [('Abnormal lung development', 89), ('Abnormal embryonic development', 83)]
# gait abnormality :  [('EEG abnormality', 85), ('EMG abnormality', 85)]
# mild short stature :  [('Mild', 100), ('Mild short stature', 100)]
# arthralgia :  [('Arthralgia', 100), ('Arthralgia of the hip', 100)]
# joint stiffness :  [('Joint stiffness', 100), ('Aortic stiffness', 77)]
# limited mobility hip :  [('Limited mobility of proximal interphalangeal joint', 89), ('Limited hip movement', 75)]
# irregular acetabulum :  [('Irregular acetabular roof', 80), ('Trident acetabulum', 71)]
# hip :  [('Abnormal hip bone morphology', 100), ('Abnormal hip joint morphology', 100)]
# knee pain :  [('Knee pain', 100), ('Pain', 100)]
# coxa vara :  [('Coxa vara', 100), ('Coxa valga', 84)]
# mild spinal change :  [('Mild', 100), ('Mild hearing impairment', 63)]
# disproportionate short stature :  [('Disproportionate short stature', 100), ('Disproportionate short-limb short stature', 100)]
# short limb :  [('Childhood onset short-limb short stature', 100), ('Disproportionate short-limb short stature', 100)]
# digit :  [('Abnormal digit morphology', 100), ('Flexion contracture of digit', 100)]
# tracheobronchial malacia :  [('Abnormal tracheobronchial morphology', 80), ('Neoplasm of the tracheobronchial system', 80)]
# progressive thoracolumbar scoliosis :  [('Progressive', 100), ('Scoliosis', 100)]
# radiographic imaging :  [('Mass on thoracic imaging', 64), ('Brain imaging abnormality', 62)]
# progression :  [('Pace of progression', 100), ('Variable progression rate', 100)]
# metaphyseal dysplasia tubular bone childhood short :  [('Metaphyseal dysplasia', 100), ('Hip dysplasia', 82)]
# broad bone :  [('Broad long bone diaphyses', 100), ('Broad toe', 84)]
# mild dysplasia joint adulthood :  [('Mild', 100), ('Hip dysplasia', 82)]
# description literature 1982 :  [('Glomerular C3 deposition', 59), ('Deviation of the 2nd finger', 56)]
# mild severe short stature :  [('Mild', 100), ('Mild short stature', 100)]
# brachydactyly :  [('Brachydactyly', 100), ('Type A brachydactyly', 100)]
# retinal degeneration :  [('Lattice retinal degeneration', 100), ('Peripheral cystoid retinal degeneration', 100)]
# variable intellectual disability :  [('Intellectual disability', 100), ('Intellectual disability, mild', 90)]
# developmental delay :  [('Global developmental delay', 100), ('Mild global developmental delay', 100)]
# craniofacial anomaly :  [('Craniofacial teratoma', 83), ('Branchial anomaly', 81)]
# clinical phenotype combine feature different sulfatase deficiency neonatal :  [('Neonatal death', 73), ('Neonatal onset', 73)]
# infantile :  [('Acute infantile spinal muscular atrophy', 100), ('Calcific stippling of infantile cartilaginous skeleton', 100)]
# juvenile presentation :  [('Breech presentation', 77), ('Complete breech presentation', 73)]
# manifestation :  [('Agitation', 73), ('Maceration', 70)]
# hypotonia :  [('Appendicular hypotonia', 100), ('Axial hypotonia', 100)]
# coarse facial feature :  [('Coarse facial features', 98), ('Fractured facial bone', 76)]
# mild deafness :  [('Mild', 100), ('Unilateral deafness', 76)]
# skeletal anomaly :  [('Fetal anomaly', 83), ('Sprengel anomaly', 75)]
# ichthyosis :  [('Generalized ichthyosis', 100), ('Ichthyosis', 100)]
# hepatomegaly :  [('Fluctuating hepatomegaly', 100), ('Hepatomegaly', 100)]
# developmental delay :  [('Global developmental delay', 100), ('Mild global developmental delay', 100)]
# progressive neurologic deterioration :  [('Progressive', 100), ('Progressive neurologic deterioration', 100)]
# hydrocephalus :  [('Communicating hydrocephalus', 100), ('Hydrocephalus', 100)]
# developmental delay varying severity :  [('Severity', 100), ('Global developmental delay', 84)]
# hearing loss :  [('Aminoglycoside-induced hearing loss', 100), ('Low-frequency hearing loss', 100)]
# manifest wide phenotypic heterogeneity :  [('Phenotypic abnormality', 62), ('Phenotypic variability', 62)]
# developmental delay varying severity :  [('Severity', 100), ('Global developmental delay', 84)]
# hearing loss :  [('Aminoglycoside-induced hearing loss', 100), ('Low-frequency hearing loss', 100)]
# manifest wide phenotypic heterogeneity :  [('Phenotypic abnormality', 62), ('Phenotypic variability', 62)]
# mild developmental delay :  [('Mild', 100), ('Mild global developmental delay', 100)]

# %%
for disease in terms_to_compare[1:10]:
    for word in disease:
        print(word, ': ',process.extract(word, hpo_list, limit=2))
        
        # immune deficiency 91, hip 90, not this one, other stuff a bit off too
# Out:
# strikingly small secondary ossification center :  [('Abnormal bone ossification', 86), ('Abnormal humeral ossification', 86)]
# joint :  [('Abnormal hip joint morphology', 90), ('Abnormal joint morphology', 90)]
# severe bone dysplasia proximal femoral head :  [('Proximal', 90), ('Severe', 90)]
# short stature :  [('Short stature', 100), ('Mild short stature', 95)]
# increased lumbar lordosis :  [('Absent spinous processes of lower thoracic and lumbar vertebrae', 86), ('Decreased anterioposterior diameter of lumbar vertebral bodies', 86)]
# genu vara :  [('Genu recurvatum', 86), ('Genu varum', 84)]
# generalized joint laxity reported :  [('Generalized joint laxity', 95), ('Generalized', 90)]
# immune deficiency :  [('Immunodeficiency', 91), ('Abnormal cellular immune system morphology', 86)]
# facial :  [('Abnormal facial artery morphology', 90), ('Abnormal facial expression', 90)]
# skeletal abnormality :  [('Abnormal fetal skeletal morphology', 86), ('Abnormal skeletal muscle morphology', 86)]
# hearing impairment :  [('Hearing impairment', 100), ('Mild hearing impairment', 95)]
# intellectual deficit :  [('Attention deficit hyperactivity disorder', 86), ('Deficit in phonologic short-term memory', 86)]
# severe :  [('Severe', 100), ('Intellectual disability, severe', 90)]
# early-onset dysplasia proximal femur :  [('Onset', 90), ('Proximal', 90)]
# complete absence secondary ossification center :  [('Abnormal bone ossification', 86), ('Abnormal humeral ossification', 86)]
# abnormal development femoral neck :  [('Abnormal B cell count', 86), ('Abnormal CD4-positive, CD25-positive, alpha-beta regulatory T cell count', 86)]
# gait abnormality :  [('Abnormality iris morphology', 86), ('Abnormality morphology of the macular vasculature', 86)]
# mild short stature :  [('Mild short stature', 100), ('Short stature', 95)]
# arthralgia :  [('Arthralgia', 100), ('Arthralgia of the hip', 90)]
# joint stiffness :  [('Joint stiffness', 100), ('Abnormal hip joint morphology', 86)]
# limited mobility hip :  [('Abnormality of hand joint mobility', 86), ('Abnormality of the hip-girdle musculature', 86)]
# irregular acetabulum :  [('Abnormal acetabulum morphology', 86), ('EEG with irregular generalized spike and wave complexes', 86)]
# hip :  [('Arthralgia of the hip', 90), ('Decreased hip abduction', 90)]
# knee pain :  [('Knee pain', 100), ('Pain', 90)]
# coxa vara :  [('Coxa vara', 100), ('Bilateral coxa valga', 86)]
# mild spinal change :  [('Mild', 90), ('Abnormal spinal cord physiology', 86)]
# disproportionate short stature :  [('Disproportionate short stature', 100), ('Disproportionate short-limb short stature', 95)]
# short limb :  [('Childhood onset short-limb short stature', 90), ('Disproportionate short-limb short stature', 90)]
# digit :  [('Abnormal digit morphology', 90), ('Autoamputation of digits', 90)]
# tracheobronchial malacia :  [('Tracheobronchomalacia', 89), ('Abnormal tracheobronchial morphology', 86)]
# progressive thoracolumbar scoliosis :  [('Lumbar scoliosis', 90), ('Progressive', 90)]
# radiographic imaging :  [('Abnormal cardiac magnetic resonance imaging finding', 86), ('Abnormal fundus autofluorescence imaging', 86)]
# progression :  [('Pace of progression', 90), ('Variable progression rate', 90)]
# metaphyseal dysplasia tubular bone childhood short :  [('Metaphyseal dysplasia', 90), ('Abnormal bone ossification', 86)]
# broad bone :  [('Abnormal bone collagen fibril morphology', 86), ('Abnormal bone ossification', 86)]
# mild dysplasia joint adulthood :  [('Mild', 90), ('Abnormal metacarpophalangeal joint morphology', 86)]
# description literature 1982 :  [('Lateral', 64), ('Bone fracture', 62)]
# mild severe short stature :  [('Mild short stature', 95), ('Severe short stature', 95)]
# brachydactyly :  [('Brachydactyly', 100), ('Type A brachydactyly', 90)]
# retinal degeneration :  [('Retinal degeneration', 100), ('Lattice retinal degeneration', 95)]
# variable intellectual disability :  [('Intellectual disability', 95), ('Intellectual disability, mild', 86)]
# developmental delay :  [('Global developmental delay', 95), ('Mild global developmental delay', 90)]
# craniofacial anomaly :  [('Anomaly of lower limb diaphyses', 86), ('Anomaly of the upper limb diaphyses', 86)]
# clinical phenotype combine feature different sulfatase deficiency neonatal :  [('Abnormal cellular phenotype', 86), ('Abnormal iduronate sulfatase concentration', 86)]
# infantile :  [('Acute infantile spinal muscular atrophy', 90), ('Calcific stippling of infantile cartilaginous skeleton', 90)]
# juvenile presentation :  [('Juvenile epithelial corneal dystrophy', 86), ('Juvenile gastrointestinal polyposis', 86)]
# manifestation :  [('Dermatological manifestations of systemic disorders', 90), ('Frequent Giardia lamblia infestation', 76)]
# hypotonia :  [('Hypotonia', 100), ('Appendicular hypotonia', 90)]
# coarse facial feature :  [('Coarse facial features', 98), ('Abnormal facial artery morphology', 86)]
# mild deafness :  [('Mild', 90), ('Intellectual disability, mild', 86)]
# skeletal anomaly :  [('Abnormal fetal skeletal morphology', 86), ('Abnormal skeletal morphology', 86)]
# ichthyosis :  [('Ichthyosis', 100), ('Generalized ichthyosis', 90)]
# hepatomegaly :  [('Hepatomegaly', 100), ('Fluctuating hepatomegaly', 90)]
# developmental delay :  [('Global developmental delay', 95), ('Mild global developmental delay', 90)]
# progressive neurologic deterioration :  [('Progressive neurologic deterioration', 100), ('Progressive', 90)]
# hydrocephalus :  [('Hydrocephalus', 100), ('Communicating hydrocephalus', 90)]
# developmental delay varying severity :  [('Severity', 90), ('Developmental cataract', 86)]
# hearing loss :  [('Aminoglycoside-induced hearing loss', 90), ('Low-frequency hearing loss', 90)]
# manifest wide phenotypic heterogeneity :  [('Phenotypic abnormality', 86), ('Phenotypic variability', 86)]
# developmental delay varying severity :  [('Severity', 90), ('Developmental cataract', 86)]
# hearing loss :  [('Aminoglycoside-induced hearing loss', 90), ('Low-frequency hearing loss', 90)]
# manifest wide phenotypic heterogeneity :  [('Phenotypic abnormality', 86), ('Phenotypic variability', 86)]
# mild developmental delay :  [('Mild global developmental delay', 95), ('Mild', 90)]

# %%
#display(token_list)
lemmatized
token_list_clean[7899:7935]
len(orpha_tokens)
list(orpha_terms.items())[400:440]
# Out:
# [(168555,
#   ['disproportionate short stature',
#    'severe femoral neck deformity',
#    'metaphyseal abnormality',
#    'platyspondyly consisting ovoid vertebral body anterior tongue-like deformity']),
#  (1162,
#   ['disproportionate short stature',
#    'severe femoral neck deformity',
#    'metaphyseal abnormality',
#    'platyspondyly consisting ovoid vertebral body anterior tongue-like deformity']),
#  (168558,
#   ['severe',
#    'early-onset',
#    'salt-wasting adrenal insufficiency',
#    'ambiguous/female external genitalia mutation < > cyp11a1 < /i > gene',
#    'milder case',
#    'delayed onset adrenal gland dysfunction',
#    'genitalia phenotype range normal male female individual',
#    '46 , xy karyotype',
#    'imaging study reveal hypoplastic/absent adrenal gland',
#    'biochemical finding',
#    'low serum cortisol',
#    'mineralocorticoid',
#    'androgen',
#    'sodium',
#    'elevated potassium level']),
#  (168563,
#   ['partial',
#    'complete gonadal dysgenesis',
#    'usually manifesting',
#    'primary amenorrhea individual',
#    'female phenotype 46 , xy karyotype',
#    'sensorimotor dysmyelinating minifascicular polyneuropathy',
#    'numbness',
#    'weakness',
#    'exercise-induced muscle cramp',
#    'sensory disturbance',
#    'reduced/absent deep tendon reflex',
#    'germ cell tumor develop gonadal tissue']),
#  (1310,
#   ['acute inflammation',
#    'massive subperiosteal new bone formation usually involving diaphysis long bone',
#    'rib',
#    'mandible',
#    'scapula',
#    'clavicle',
#    'disease',
#    'fever',
#    'irritability pain',
#    'soft tissue swelling',
#    'age 2 month',
#    'resolving spontaneously age 2 year',
#    'prenatal disease onset described']),
#  (168569,
#   ['hyperpigmentation',
#    'hypertrichosis',
#    'hepatosplenomegaly',
#    'heart anomaly',
#    'hearing loss',
#    'hypogonadism',
#    'low height',
#    'occasionally',
#    'hyperglycemia/diabetes mellitus',
#    'overlapping clinical feature',
#    'considered',
#    'pigmented hypertrichosis',
#    'insulin dependent diabetes mellitus syndrome',
#    'faisalabad histiocytosis',
#    'familial sinus histiocytosis',
#    'massive lymphadenopathy',
#    'case dysosteosclerosis',
#    'syndrome']),
#  (168572,
#   ['weakness',
#    'arthrogryposis',
#    'kyphoscoliosis',
#    'short stature',
#    'cleft palate',
#    'ptosis',
#    'susceptibility malignant hyperthermia anesthesia']),
#  (168443,
#   ['congenital hypotrichosis',
#    'rhizomelic short stature',
#    'limited hip abduction',
#    'mild genu varum',
#    'flared',
#    'irregular metaphyses',
#    'delayed',
#    'irregular epiphiseal ossification',
#    'pear-shaped vertebral body characteristic radiologic finding']),
#  (1065,
#   ['association partial bilateral aniridia',
#    'non-progressive cerebellar ataxia',
#    'intellectual disability']),
#  (168448,
#   ['association partial bilateral aniridia',
#    'non-progressive cerebellar ataxia',
#    'intellectual disability']),
#  (168451,
#   ['association dental anomaly',
#    'generalized platyspondyly',
#    'epiphyseal',
#    'metaphyseal involvement',
#    'thin tapering finger',
#    'accentuated palmar crease additional feature']),
#  (1135,
#   ['complete',
#    'incomplete absence nose',
#    'choanal atresia',
#    'microphthalmia',
#    'anophthalmia',
#    'cleft',
#    'high palate']),
#  (168454,
#   ['severe developmental delay',
#    'skeletal dysplasia',
#    'moderate severe intellectual disability',
#    'facial dysmorphism',
#    'prominent forehead',
#    'mild synophrys',
#    'depressed nasal bridge',
#    'prominent bulbous nasal tip',
#    'lip']),
#  (1146,
#   ['contracture distal region hand',
#    'foot absence primary neurological and/or muscle disease affecting limb function',
#    'facial involvement limited small mouth',
#    'impaired mouth opening',
#    'additional anomaly reported']),
#  (1143,
#   ['congenital immobility limb',
#    'fixation multiple joint',
#    'muscle wasting',
#    'condition secondary neurogenic muscular atrophy']),
#  (168486,
#   ['primary microcephaly', 'neonatal epilepsy', 'death early infancy']),
#  (168491,
#   ['onset infancy',
#    'early childhood',
#    'decline mental',
#    'motor capacity',
#    'epilepsy',
#    'vision loss retinal degeneration']),
#  (168544,
#   ['severe short stature',
#    'coarse facies',
#    'thoracolumbar kyphoscoliosis',
#    'enlarged joint',
#    'contracture',
#    'psychomotor delay',
#    'intellectual disability',
#    'radiographic feature',
#    'flat vertebral body',
#    'lacy ossification metaphyses long bone',
#    'iliac crest',
#    'sclerosis skull base']),
#  (1147,
#   ['contracture distal joint limb',
#    'triangular face',
#    'downslanting palpebral fissure',
#    'small mouth',
#    'high arched palate']),
#  (246,
#   ['mandibular',
#    'malar hypoplasia',
#    'small',
#    'cup-shaped ear',
#    'lower lid ectropion',
#    'symmetrical postaxial limb deficiency',
#    'absence fifth digital ray',
#    'ulnar hypoplasia']),
#  (1819,
#   ['mandibular',
#    'malar hypoplasia',
#    'small',
#    'cup-shaped ear',
#    'lower lid ectropion',
#    'symmetrical postaxial limb deficiency',
#    'absence fifth digital ray',
#    'ulnar hypoplasia']),
#  (1770,
#   ['mild developmental delay',
#    'streak gonad',
#    'short stature',
#    'cardiac',
#    'renal',
#    'musculoskeletal',
#    'ectodermal abnormality',
#    'dysmorphic facial feature',
#    'description literature 1980']),
#  (1764,
#   ['decreased pain',
#    'temperature perception',
#    'absent deep tendon reflex',
#    'proprioceptive ataxia',
#    'afferent baroreflex failure',
#    'progressive optic neuropathy']),
#  (239,
#   ['progressive short-trunked dwarfism',
#    'protruding sternum',
#    'microcephaly',
#    'intellectual disability',
#    'pathognomonic radiological finding']),
#  (167762,
#   ['progressive short-trunked dwarfism',
#    'protruding sternum',
#    'microcephaly',
#    'intellectual disability',
#    'pathognomonic radiological finding']),
#  (1672,
#   ['profound emaciation',
#    'failure thrive',
#    'hyperalertness',
#    'hyperkinesia',
#    'euphoria',
#    'presence hypothalamic tumor']),
#  (167759,
#   ['abnormal dentin structure affecting primary',
#    'primary',
#    'secondary dentition']),
#  (833, ['seizure', 'progressive encephalopathy', 'lens dislocation']),
#  (167714, ['seizure', 'progressive encephalopathy', 'lens dislocation']),
#  (167635,
#   ['progressive',
#    'generalized',
#    'papular',
#    'sclerodermoid cutaneous eruption usually occurring association',
#    'monoclonal gammopathy',
#    'absence thyroid disease',
#    'histological hallmark triad dermal mucin deposition',
#    'fibroblast proliferation',
#    'fibrosis',
#    'patient',
#    'relatively sudden onset numerous closely spaced',
#    'waxy',
#    'firm papule',
#    'plaque predominantly involving head',
#    'neck',
#    'trunk',
#    'dorsal aspect extremity',
#    'background thickened',
#    'edematous',
#    'erythematous skin',
#    'sclerodermoid appearance',
#    'systemic involvement',
#    'cardiovascular',
#    'gastrointestinal',
#    'pulmonary',
#    'musculoskeletal',
#    'renal',
#    'nervous system complication common']),
#  (765,
#   ['wide range clinical sign',
#    'metabolic',
#    'neurological component varying severity',
#    'manifestation range fatal',
#    'severe',
#    'neonatal lactic acidosis later-onset neurological disorder',
#    'subtypes related affected subunit pdh complex recognized',
#    'significant clinical overlap : pdhd e1-alpha',
#    'e1-beta',
#    'e2',
#    'e3 deficiency',
#    'pdhd e3-binding protein deficiency',
#    'pdh phosphatase deficiency']),
#  (395, ['neurological manifestation']),
#  (148,
#   ['reduced activity biotin-dependent enzyme',
#    'wide spectrum symptom',
#    'feeding difficulty',
#    'breathing difficulty',
#    'lethargy',
#    'seizure',
#    'skin rash',
#    'alopecia',
#    'developmental delay',
#    'group',
#    'biotinidase deficiency',
#    'biotin holocarboxylase synthetase deficiency']),
#  (147,
#   ['neonatal-onset severe hyperammonemia occurs day birth',
#    'manifest',
#    'lethargy',
#    'vomiting',
#    'hypothermia',
#    'seizure',
#    'coma',
#    'death',
#    'presentation outside newborn period age',
#    'milder symptom hyperammonemia']),
#  (23,
#   ['severe',
#    'neonatal-onset form manifest',
#    'hyperammonemia accompanied',
#    'vomiting',
#    'hypothermia',
#    'lethargy',
#    'poor feeding day life',
#    'late-onset form manifest',
#    'stress-',
#    'infection-induced episodic hyperammonemia',
#    'behavioral abnormality and/or learning disability',
#    'chronic liver disease',
#    'patient manifest liver dysfunction']),
#  (45, ['exercise-induced muscle pain', 'cramp and/or early fatigue']),
#  (166775, ['exercise-induced muscle pain', 'cramp and/or early fatigue']),
#  (217,
#   ['association sign : hydrocephalus',
#    'partial',
#    'complete absence cerebellar vermis',
#    'posterior fossa cyst contiguous',
#    'fourth ventricle',
#    'early life',
#    'hydrocephalus',
#    'bulging occiput',
#    'posterior fossa sign',
#    'cranial nerve palsy',
#    'nystagmus',
#    'ataxia']),
#  (1564,
#   ['association sign : hydrocephalus',
#    'partial',
#    'complete absence cerebellar vermis',
#    'posterior fossa cyst contiguous',
#    'fourth ventricle',
#    'early life',
#    'hydrocephalus',
#    'bulging occiput',
#    'posterior fossa sign',
#    'cranial nerve palsy',
#    'nystagmus',
#    'ataxia']),
#  (1556,
#   ['persistent cutis marmorata pattern',
#    'marbled bluish deep purple appearance',
#    'spider nevus-like telangiectasia',
#    'phlebectasia',
#    'occasionally',
#    'ulceration',
#    'atrophy affected skin'])]

# %%
orpha_tokens
# Out:
# {3186: ['holoprosencephaly',
#   'predominantly radial limb deficiency',
#   'heart defects',
#   'kidney malformations',
#   'absence of gallbladder',
#   'variable manifestations',
#   'vertebral anomalies',
#   'cleft lip/palate',
#   'microphthalmia',
#   'absent nose',
#   'dysplastic ears',
#   'hearing loss',
#   'colobomas of the iris',
#   'retina and/or bifid uvula',
#   ''],
#  3191: ['the association of short stature',
#   'progressive discrete subaortic stenosis',
#   'additional variable manifestations',
#   'upturned nose',
#   'voice',
#   'vocal cord abnormalities',
#   'obstructive lung disease',
#   'inguinal hernia',
#   'kyphoscoliosis and',
#   'occasionally',
#   'epicanthus',
#   'strabismus',
#   'microphthalmos',
#   'widely spaced teeth',
#   'there have been no further descriptions in the literature since 1984',
#   ''],
#  3193: ['the narrowing of the aorta lumen',
#   '',
#   'not',
#   'stenosis of other arteries',
#   'this narrowing of the aorta',
#   'pulmonary branches may impede blood flow',
#   '',
#   'in heart murmur',
#   'ventricular hypertrophy',
#   ''],
#  280356: ['loss of subcutaneous adipose tissue primarily affecting the lower limbs',
#   'gluteal region due to a defect in the plin1 gene',
#   '',
#   'features of insulin resistance',
#   'hepatic steatosis',
#   'dyslipidemia',
#   'hypertension',
#   'axillary acanthosis nigricans',
#   'muscular hypertrophy of the lower limbs are typical',
#   ''],
#  3214: ['cutaneous pigmentation anomalies',
#   'ocular disorders',
#   'hearing loss',
#   ''],
#  280400: ['cutaneous pigmentation anomalies',
#   'ocular disorders',
#   'hearing loss',
#   ''],
#  280403: ['omphalocele',
#   '',
#   'facial dysmorphism',
#   'flat face',
#   'short',
#   'upturned nose',
#   'long',
#   'wide philtrum',
#   'flattened maxillary arch',
#   'abnormalities of hands',
#   ''],
#  3213: ['omphalocele',
#   '',
#   'facial dysmorphism',
#   'flat face',
#   'short',
#   'upturned nose',
#   'long',
#   'wide philtrum',
#   'flattened maxillary arch',
#   'abnormalities of hands',
#   ''],
#  280406: ['sensorineural deafness',
#   'severe',
#   'progressive nephrotic syndrome not responding to steroid treatment',
#   'clinical manifestations',
#   'early onset proteinuria',
#   'hypoalbuminemia',
#   'edema',
#   'leading to end-stage renal disease',
#   'the renal biopsy reveals focal segmental glomerulosclerosis',
#   'diffuse mesangial sclerosis',
#   'rarely',
#   'seizures',
#   'ataxia',
#   'dysmorphic features have been described',
#   ''],
#  3215: ['sensorineural deafness',
#   'severe',
#   'progressive nephrotic syndrome not responding to steroid treatment',
#   'clinical manifestations',
#   'early onset proteinuria',
#   'hypoalbuminemia',
#   'edema',
#   'leading to end-stage renal disease',
#   'the renal biopsy reveals focal segmental glomerulosclerosis',
#   'diffuse mesangial sclerosis',
#   'rarely',
#   'seizures',
#   'ataxia',
#   'dysmorphic features have been described',
#   ''],
#  3210: ['',
#   'malformations of the head',
#   'face',
#   'broad depressed nasal bridge',
#   'narrow maxillae',
#   'abnormalities of the hands',
#   'feet',
#   'obesity',
#   'congenital heart disease',
#   'this disease is considered a variant of carpenter syndrome',
#   'out intellectual disabaility',
#   'there have been no further descriptions in the literature since 1992',
#   ''],
#  3201: ['cardiac arrhythmias', 'perodactyly', 'pierre-robin sequence', ''],
#  280384: ['severe intellectual disability',
#   'progressive',
#   'postnatal',
#   'multiple joint contractures',
#   'severe motor dysfunction',
#   'patients',
#   'arrest',
#   'regression of motor function',
#   'speech acquisition',
#   'as well as contractures which begin in lower limbs',
#   'slowly progress in an ascending manner to',
#   'spine',
#   'neck',
#   '',
#   'in individuals',
#   'a specific fixed position',
#   ''],
#  3212: ['severe intellectual disability',
#   'progressive',
#   'postnatal',
#   'multiple joint contractures',
#   'severe motor dysfunction',
#   'patients',
#   'arrest',
#   'regression of motor function',
#   'speech acquisition',
#   'as well as contractures which begin in lower limbs',
#   'slowly progress in an ascending manner to',
#   'spine',
#   'neck',
#   '',
#   'in individuals',
#   'a specific fixed position',
#   ''],
#  280397: ['the neuropathological features of alzheimer disease',
#   'memory impairment',
#   'depression',
#   'related to abnormal prion protein  caused by a gene mutation in <i>prnp</i>',
#   'patients',
#   '',
#   'a prolonged',
#   'atypical course  unlike other forms of prion disease',
#   'severe neurofibrillary tangle pathology',
#   'high levels of cerebral amyloidosis',
#   ''],
#  280576: ['a prematurely aged appearance',
#   '',
#   'severe osteolysis',
#   'osteoporosis',
#   'generalized lipoatrophy',
#   'absence of cardiovascular',
#   'atherosclerotic',
#   'metabolic complications',
#   '',
#   'a relatively long survival',
#   'additional characteristics',
#   'growth retardation',
#   'joint stiffness',
#   'wide cranial sutures',
#   'dysmorphic facial features',
#   'persistent eyebrows',
#   'eyelashes',
#   'scalp hair',
#   ''],
#  3220: ['sensorineural hearing loss',
#   'abnormalities in the secondary dentition',
#   'and nail abnormalities',
#   'association',
#   'macular dystrophy has also been reported',
#   ''],
#  3219: ['intellectual disability',
#   'deafness',
#   'skeletal abnormalities',
#   'coarse facial features',
#   ''],
#  3222: ['gout',
#   'urolithiasis',
#   'and neurodevelopmental anomalies',
#   'a mild late-onset form',
#   'no neurologic involvement',
#   ''],
#  280586: ['prenatal onset of disproportionate short stature',
#   'shortening of the limbs',
#   'congenital joint dislocations',
#   'micrognathia',
#   'posterior cleft palate',
#   'brachydactyly',
#   'short metacarpals',
#   'irregular size of the metacarpal epiphyses',
#   'supernumerary carpal ossification centers',
#   'dysmorphic facial features',
#   'in addition',
#   'hearing impairment',
#   'mild psychomotor delay have also been reported',
#   '']}

# %%
##installation of modules
##!pip install -U pip setuptools wheel
##!pip install spacy
#! pip install transformers
#import spacy
#from spacy.lang.en.stop_words import STOP_WORDS
# start with small pretrained model
#nlp = spacy.load('en_core_web_sm')
#import medspacy

# start with small pretrained model
#nlp = spacy.load('en_core_web_sm')

# %%
test=[.']
nlp = medspacy.load()'A rare severe, X-linked, neurodevelopmental disorder characterised by rapid developmental regression in infancy, partial or complete loss of purposeful hand movements, loss of speech, gait abnormalities, and stereotypic hand movements, commonly associated with deceleration of head growth, severe intellectual disability, seizures, and breathing abnormalities. The disorder has a progressive clinical course and \
        may associate various comorbidities including gastrointestinal diseases, scoliosis, and behavioral disorders
print(nlp.pipe_names)
# nlp.get_pipe(test)
doc = nlp(test)
doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35556\413900154.py in <module>
#       1 test=['A rare severe, X-linked, neurodevelopmental disorder characterised by rapid developmental regression in infancy, partial or complete loss of purposeful hand movements, loss of speech, gait abnormalities, and stereotypic hand movements, commonly associated with deceleration of head growth, severe intellectual disability, seizures, and breathing abnormalities. The disorder has a progressive clinical course and \
#       2         may associate various comorbidities including gastrointestinal diseases, scoliosis, and behavioral disorders.']
# ----> 3 nlp = medspacy.load()
#       4 print(nlp.pipe_names)
#       5 # nlp.get_pipe(test)
#
# NameError: name 'medspacy' is not defined

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
import torch

# %%
from transformers import pipeline
# Load the clinicalBERT tokenizer and model for token classification
tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = AutoModelForTokenClassification.from_pretrained("emilyalsentzer/Bio_ClinicalBERT", num_labels=3)
nerpipeline = pipeline('ner', model=model, tokenizer=tokenizer)
nerpipeline(input_text)
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'LABEL_2',
#   'score': 0.37690538,
#   'index': 1,
#   'word': 'a',
#   'start': 0,
#   'end': 1},
#  {'entity': 'LABEL_0',
#   'score': 0.41044927,
#   'index': 2,
#   'word': 'rare',
#   'start': 2,
#   'end': 6},
#  {'entity': 'LABEL_0',
#   'score': 0.4596424,
#   'index': 3,
#   'word': 'severe',
#   'start': 7,
#   'end': 13},
#  {'entity': 'LABEL_0',
#   'score': 0.4858439,
#   'index': 4,
#   'word': ',',
#   'start': 13,
#   'end': 14},
#  {'entity': 'LABEL_0',
#   'score': 0.47528505,
#   'index': 5,
#   'word': 'x',
#   'start': 15,
#   'end': 16},
#  {'entity': 'LABEL_0',
#   'score': 0.3844964,
#   'index': 6,
#   'word': '-',
#   'start': 16,
#   'end': 17},
#  {'entity': 'LABEL_0',
#   'score': 0.46289796,
#   'index': 7,
#   'word': 'linked',
#   'start': 17,
#   'end': 23},
#  {'entity': 'LABEL_0',
#   'score': 0.4469681,
#   'index': 8,
#   'word': ',',
#   'start': 23,
#   'end': 24},
#  {'entity': 'LABEL_0',
#   'score': 0.47196826,
#   'index': 9,
#   'word': 'ne',
#   'start': 25,
#   'end': 27},
#  {'entity': 'LABEL_0',
#   'score': 0.43037152,
#   'index': 10,
#   'word': '##uro',
#   'start': 27,
#   'end': 30},
#  {'entity': 'LABEL_0',
#   'score': 0.391064,
#   'index': 11,
#   'word': '##de',
#   'start': 30,
#   'end': 32},
#  {'entity': 'LABEL_2',
#   'score': 0.3992632,
#   'index': 12,
#   'word': '##vel',
#   'start': 32,
#   'end': 35},
#  {'entity': 'LABEL_2',
#   'score': 0.39689884,
#   'index': 13,
#   'word': '##op',
#   'start': 35,
#   'end': 37},
#  {'entity': 'LABEL_0',
#   'score': 0.37662676,
#   'index': 14,
#   'word': '##mental',
#   'start': 37,
#   'end': 43},
#  {'entity': 'LABEL_0',
#   'score': 0.37280568,
#   'index': 15,
#   'word': 'disorder',
#   'start': 44,
#   'end': 52},
#  {'entity': 'LABEL_0',
#   'score': 0.37564135,
#   'index': 16,
#   'word': 'characterised',
#   'start': 53,
#   'end': 66},
#  {'entity': 'LABEL_0',
#   'score': 0.41929132,
#   'index': 17,
#   'word': 'by',
#   'start': 67,
#   'end': 69},
#  {'entity': 'LABEL_0',
#   'score': 0.4041467,
#   'index': 18,
#   'word': 'rapid',
#   'start': 70,
#   'end': 75},
#  {'entity': 'LABEL_0',
#   'score': 0.39077917,
#   'index': 19,
#   'word': 'developmental',
#   'start': 76,
#   'end': 89},
#  {'entity': 'LABEL_0',
#   'score': 0.3691351,
#   'index': 20,
#   'word': 're',
#   'start': 90,
#   'end': 92},
#  {'entity': 'LABEL_0',
#   'score': 0.44896984,
#   'index': 21,
#   'word': '##gression',
#   'start': 92,
#   'end': 100},
#  {'entity': 'LABEL_0',
#   'score': 0.4104088,
#   'index': 22,
#   'word': 'in',
#   'start': 101,
#   'end': 103},
#  {'entity': 'LABEL_0',
#   'score': 0.3744191,
#   'index': 23,
#   'word': 'infancy',
#   'start': 104,
#   'end': 111},
#  {'entity': 'LABEL_0',
#   'score': 0.44128245,
#   'index': 24,
#   'word': ',',
#   'start': 111,
#   'end': 112},
#  {'entity': 'LABEL_0',
#   'score': 0.3989161,
#   'index': 25,
#   'word': 'partial',
#   'start': 113,
#   'end': 120},
#  {'entity': 'LABEL_2',
#   'score': 0.3860857,
#   'index': 26,
#   'word': 'or',
#   'start': 121,
#   'end': 123},
#  {'entity': 'LABEL_0',
#   'score': 0.43047997,
#   'index': 27,
#   'word': 'complete',
#   'start': 124,
#   'end': 132},
#  {'entity': 'LABEL_0',
#   'score': 0.38175768,
#   'index': 28,
#   'word': 'loss',
#   'start': 133,
#   'end': 137},
#  {'entity': 'LABEL_0',
#   'score': 0.4486395,
#   'index': 29,
#   'word': 'of',
#   'start': 138,
#   'end': 140},
#  {'entity': 'LABEL_0',
#   'score': 0.3588642,
#   'index': 30,
#   'word': 'purpose',
#   'start': 141,
#   'end': 148},
#  {'entity': 'LABEL_0',
#   'score': 0.37785736,
#   'index': 31,
#   'word': '##ful',
#   'start': 148,
#   'end': 151},
#  {'entity': 'LABEL_0',
#   'score': 0.38913503,
#   'index': 32,
#   'word': 'hand',
#   'start': 152,
#   'end': 156},
#  {'entity': 'LABEL_0',
#   'score': 0.38116667,
#   'index': 33,
#   'word': 'movements',
#   'start': 157,
#   'end': 166},
#  {'entity': 'LABEL_0',
#   'score': 0.43608066,
#   'index': 34,
#   'word': ',',
#   'start': 166,
#   'end': 167},
#  {'entity': 'LABEL_0',
#   'score': 0.38012907,
#   'index': 35,
#   'word': 'loss',
#   'start': 168,
#   'end': 172},
#  {'entity': 'LABEL_0',
#   'score': 0.4233406,
#   'index': 36,
#   'word': 'of',
#   'start': 173,
#   'end': 175},
#  {'entity': 'LABEL_2',
#   'score': 0.38102797,
#   'index': 37,
#   'word': 'speech',
#   'start': 176,
#   'end': 182},
#  {'entity': 'LABEL_0',
#   'score': 0.48213872,
#   'index': 38,
#   'word': ',',
#   'start': 182,
#   'end': 183},
#  {'entity': 'LABEL_0',
#   'score': 0.4397383,
#   'index': 39,
#   'word': 'g',
#   'start': 184,
#   'end': 185},
#  {'entity': 'LABEL_2',
#   'score': 0.45135093,
#   'index': 40,
#   'word': '##ait',
#   'start': 185,
#   'end': 188},
#  {'entity': 'LABEL_1',
#   'score': 0.38125253,
#   'index': 41,
#   'word': 'abnormal',
#   'start': 189,
#   'end': 197},
#  {'entity': 'LABEL_2',
#   'score': 0.4028891,
#   'index': 42,
#   'word': '##ities',
#   'start': 197,
#   'end': 202},
#  {'entity': 'LABEL_0',
#   'score': 0.46306252,
#   'index': 43,
#   'word': ',',
#   'start': 202,
#   'end': 203},
#  {'entity': 'LABEL_0',
#   'score': 0.35878924,
#   'index': 44,
#   'word': 'and',
#   'start': 204,
#   'end': 207},
#  {'entity': 'LABEL_0',
#   'score': 0.4138833,
#   'index': 45,
#   'word': 'stereo',
#   'start': 208,
#   'end': 214},
#  {'entity': 'LABEL_2',
#   'score': 0.42192984,
#   'index': 46,
#   'word': '##ty',
#   'start': 214,
#   'end': 216},
#  {'entity': 'LABEL_0',
#   'score': 0.35201755,
#   'index': 47,
#   'word': '##pic',
#   'start': 216,
#   'end': 219},
#  {'entity': 'LABEL_0',
#   'score': 0.37165868,
#   'index': 48,
#   'word': 'hand',
#   'start': 220,
#   'end': 224},
#  {'entity': 'LABEL_0',
#   'score': 0.3753672,
#   'index': 49,
#   'word': 'movements',
#   'start': 225,
#   'end': 234},
#  {'entity': 'LABEL_0',
#   'score': 0.38620922,
#   'index': 50,
#   'word': ',',
#   'start': 234,
#   'end': 235},
#  {'entity': 'LABEL_0',
#   'score': 0.39609575,
#   'index': 51,
#   'word': 'commonly',
#   'start': 236,
#   'end': 244},
#  {'entity': 'LABEL_2',
#   'score': 0.40838793,
#   'index': 52,
#   'word': 'associated',
#   'start': 245,
#   'end': 255},
#  {'entity': 'LABEL_0',
#   'score': 0.40836486,
#   'index': 53,
#   'word': 'with',
#   'start': 256,
#   'end': 260},
#  {'entity': 'LABEL_0',
#   'score': 0.38866922,
#   'index': 54,
#   'word': 'de',
#   'start': 261,
#   'end': 263},
#  {'entity': 'LABEL_0',
#   'score': 0.38515192,
#   'index': 55,
#   'word': '##cel',
#   'start': 263,
#   'end': 266},
#  {'entity': 'LABEL_2',
#   'score': 0.39625803,
#   'index': 56,
#   'word': '##eration',
#   'start': 266,
#   'end': 273},
#  {'entity': 'LABEL_0',
#   'score': 0.42776954,
#   'index': 57,
#   'word': 'of',
#   'start': 274,
#   'end': 276},
#  {'entity': 'LABEL_2',
#   'score': 0.35890645,
#   'index': 58,
#   'word': 'head',
#   'start': 277,
#   'end': 281},
#  {'entity': 'LABEL_1',
#   'score': 0.33430338,
#   'index': 59,
#   'word': 'growth',
#   'start': 282,
#   'end': 288},
#  {'entity': 'LABEL_0',
#   'score': 0.40862527,
#   'index': 60,
#   'word': ',',
#   'start': 288,
#   'end': 289},
#  {'entity': 'LABEL_2',
#   'score': 0.37041748,
#   'index': 61,
#   'word': 'severe',
#   'start': 290,
#   'end': 296},
#  {'entity': 'LABEL_2',
#   'score': 0.41500923,
#   'index': 62,
#   'word': 'intellectual',
#   'start': 297,
#   'end': 309},
#  {'entity': 'LABEL_1',
#   'score': 0.39900586,
#   'index': 63,
#   'word': 'disability',
#   'start': 310,
#   'end': 320},
#  {'entity': 'LABEL_0',
#   'score': 0.42368248,
#   'index': 64,
#   'word': ',',
#   'start': 320,
#   'end': 321},
#  {'entity': 'LABEL_0',
#   'score': 0.3811611,
#   'index': 65,
#   'word': 'seizure',
#   'start': 322,
#   'end': 329},
#  {'entity': 'LABEL_2',
#   'score': 0.36313573,
#   'index': 66,
#   'word': '##s',
#   'start': 329,
#   'end': 330},
#  {'entity': 'LABEL_0',
#   'score': 0.4372768,
#   'index': 67,
#   'word': ',',
#   'start': 330,
#   'end': 331},
#  {'entity': 'LABEL_0',
#   'score': 0.40779787,
#   'index': 68,
#   'word': 'and',
#   'start': 332,
#   'end': 335},
#  {'entity': 'LABEL_0',
#   'score': 0.38006705,
#   'index': 69,
#   'word': 'breathing',
#   'start': 336,
#   'end': 345},
#  {'entity': 'LABEL_1',
#   'score': 0.3909378,
#   'index': 70,
#   'word': 'abnormal',
#   'start': 346,
#   'end': 354},
#  {'entity': 'LABEL_0',
#   'score': 0.34805816,
#   'index': 71,
#   'word': '##ities',
#   'start': 354,
#   'end': 359},
#  {'entity': 'LABEL_2',
#   'score': 0.4350468,
#   'index': 72,
#   'word': '.',
#   'start': 359,
#   'end': 360},
#  {'entity': 'LABEL_2',
#   'score': 0.42997426,
#   'index': 73,
#   'word': 'the',
#   'start': 361,
#   'end': 364},
#  {'entity': 'LABEL_2',
#   'score': 0.3701971,
#   'index': 74,
#   'word': 'disorder',
#   'start': 365,
#   'end': 373},
#  {'entity': 'LABEL_2',
#   'score': 0.47849518,
#   'index': 75,
#   'word': 'has',
#   'start': 374,
#   'end': 377},
#  {'entity': 'LABEL_2',
#   'score': 0.4174446,
#   'index': 76,
#   'word': 'a',
#   'start': 378,
#   'end': 379},
#  {'entity': 'LABEL_0',
#   'score': 0.40683293,
#   'index': 77,
#   'word': 'progressive',
#   'start': 380,
#   'end': 391},
#  {'entity': 'LABEL_2',
#   'score': 0.45663944,
#   'index': 78,
#   'word': 'clinical',
#   'start': 392,
#   'end': 400},
#  {'entity': 'LABEL_2',
#   'score': 0.41800782,
#   'index': 79,
#   'word': 'course',
#   'start': 401,
#   'end': 407},
#  {'entity': 'LABEL_2',
#   'score': 0.4192559,
#   'index': 80,
#   'word': 'and',
#   'start': 408,
#   'end': 411},
#  {'entity': 'LABEL_2',
#   'score': 0.4222095,
#   'index': 81,
#   'word': 'may',
#   'start': 412,
#   'end': 415},
#  {'entity': 'LABEL_2',
#   'score': 0.46248186,
#   'index': 82,
#   'word': 'associate',
#   'start': 416,
#   'end': 425},
#  {'entity': 'LABEL_2',
#   'score': 0.40629274,
#   'index': 83,
#   'word': 'various',
#   'start': 426,
#   'end': 433},
#  {'entity': 'LABEL_2',
#   'score': 0.47112405,
#   'index': 84,
#   'word': 'com',
#   'start': 434,
#   'end': 437},
#  {'entity': 'LABEL_2',
#   'score': 0.5058797,
#   'index': 85,
#   'word': '##or',
#   'start': 437,
#   'end': 439},
#  {'entity': 'LABEL_0',
#   'score': 0.40789008,
#   'index': 86,
#   'word': '##bid',
#   'start': 439,
#   'end': 442},
#  {'entity': 'LABEL_2',
#   'score': 0.4872958,
#   'index': 87,
#   'word': '##ities',
#   'start': 442,
#   'end': 447},
#  {'entity': 'LABEL_2',
#   'score': 0.39004496,
#   'index': 88,
#   'word': 'including',
#   'start': 448,
#   'end': 457},
#  {'entity': 'LABEL_2',
#   'score': 0.42289552,
#   'index': 89,
#   'word': 'gas',
#   'start': 458,
#   'end': 461},
#  {'entity': 'LABEL_0',
#   'score': 0.42060173,
#   'index': 90,
#   'word': '##tro',
#   'start': 461,
#   'end': 464},
#  {'entity': 'LABEL_0',
#   'score': 0.40510923,
#   'index': 91,
#   'word': '##int',
#   'start': 464,
#   'end': 467},
#  {'entity': 'LABEL_2',
#   'score': 0.39957812,
#   'index': 92,
#   'word': '##est',
#   'start': 467,
#   'end': 470},
#  {'entity': 'LABEL_0',
#   'score': 0.38661692,
#   'index': 93,
#   'word': '##inal',
#   'start': 470,
#   'end': 474},
#  {'entity': 'LABEL_0',
#   'score': 0.42129123,
#   'index': 94,
#   'word': 'diseases',
#   'start': 475,
#   'end': 483},
#  {'entity': 'LABEL_0',
#   'score': 0.4262814,
#   'index': 95,
#   'word': ',',
#   'start': 483,
#   'end': 484},
#  {'entity': 'LABEL_0',
#   'score': 0.3646699,
#   'index': 96,
#   'word': 's',
#   'start': 485,
#   'end': 486},
#  {'entity': 'LABEL_2',
#   'score': 0.37770924,
#   'index': 97,
#   'word': '##co',
#   'start': 486,
#   'end': 488},
#  {'entity': 'LABEL_2',
#   'score': 0.3623868,
#   'index': 98,
#   'word': '##lio',
#   'start': 488,
#   'end': 491},
#  {'entity': 'LABEL_2',
#   'score': 0.47863004,
#   'index': 99,
#   'word': '##sis',
#   'start': 491,
#   'end': 494},
#  {'entity': 'LABEL_0',
#   'score': 0.43956986,
#   'index': 100,
#   'word': ',',
#   'start': 494,
#   'end': 495},
#  {'entity': 'LABEL_0',
#   'score': 0.38078555,
#   'index': 101,
#   'word': 'and',
#   'start': 496,
#   'end': 499},
#  {'entity': 'LABEL_0',
#   'score': 0.3842084,
#   'index': 102,
#   'word': 'behavioral',
#   'start': 500,
#   'end': 510},
#  {'entity': 'LABEL_2',
#   'score': 0.4236753,
#   'index': 103,
#   'word': 'disorders',
#   'start': 511,
#   'end': 520}]

# %%
# Define the input text to be processed
input_text = 'A rare severe, X-linked, neurodevelopmental disorder characterised by rapid developmental regression in infancy, partial or complete loss of purposeful hand movements, loss of speech, gait abnormalities, and stereotypic hand movements, commonly associated with deceleration of head growth, severe intellectual disability, seizures, and breathing abnormalities. The disorder has a progressive clinical course and may associate various comorbidities including gastrointestinal diseases, scoliosis, and behavioral disorders'

# Tokenize the input text
tokens = tokenizer.encode_plus(input_text, padding=True, truncation=True, return_tensors="pt")

# Classify the tokens using clinicalBERT
with torch.no_grad():
    outputs = model(tokens['input_ids'], tokens['attention_mask'])

# Get the predicted entity labels from the output
entity_labels = torch.argmax(outputs.logits, dim=2)[0]

# Map the entity labels to the corresponding entities
entities = []
for i, token in enumerate(tokenizer.tokenize(input_text)):
    if entity_labels[i] == 1:
        entities.append(token)

# Print the entities found in the input text
print("Entities found in input text:", entities)
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Entities found in input text: ['a', 'rare', ',', 'x', '-', 'linked', ',', 'ne', '##uro', '##vel', '##op', 'disorder', 'by', 'rapid', 'in', 'partial', 'complete', 'loss', 'of', 'purpose', '##ful', 'hand', 'movements', 'loss', 'of', 'g', 'abnormal', 'and', 'stereo', '##pic', 'hand', 'movements', 'commonly', 'with', 'de', '##eration', 'of', 'head', 'growth', 'severe', 'intellectual', 'disability', 'seizure', '##s', ',', 'and', 'breathing', 'abnormal', 'the', 'disorder', 'a', 'progressive', 'clinical', 'course', 'and', 'may', 'associate', 'various', 'com', '##or', '##bid', '##ities', 'including', 'gas', '##tro', '##int', '##est', '##inal', 'diseases', ',', 's', '##co', '##lio', ',', 'and', 'behavioral', 'disorders']

# %%
# the below doesnt work
tokenizer = AutoTokenizer.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")
model = AutoModelForTokenClassification.from_pretrained("emilyalsentzer/Bio_ClinicalBERT")

text = ["The patient was diagnosed with acute myeloid leukemia and started on chemotherapy."]

# Tokenize the text and convert to input format expected by the model
inputs = tokenizer(test, return_tensors="pt")

# Run the model on the inputs
outputs = model(**inputs)

# Get the predicted labels for each token
predicted_labels = outputs.logits.argmax(-1).squeeze()

# Get the list of entity labels used by the model
labels = model.config.id2label.values()

# Map the predicted labels to the entity labels
entities = []
for i, label in enumerate(predicted_labels):
    if label != 0:
        entities.append((tokenizer.convert_ids_to_tokens(inputs["input_ids"][0][i]), labels[label]))

# Print the list of entities found in the text
print(entities)
# Out:
# Some weights of the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing BertForTokenClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35556\884733403.py in <module>
#      25 for i, label in enumerate(predicted_labels):
#      26     if label != 0:
# ---> 27         entities.append((tokenizer.convert_ids_to_tokens(inputs["input_ids"][0][i]), labels[label]))
#      28
#      29 # Print the list of entities found in the text
#
# ~\anaconda3\lib\site-packages\transformers\tokenization_utils_fast.py in convert_ids_to_tokens(self, ids, skip_special_tokens)
#     310             return self._tokenizer.id_to_token(ids)
#     311         tokens = []
# --> 312         for index in ids:
#     313             index = int(index)
#     314             if skip_special_tokens and index in self.all_special_ids:
#
# ~\anaconda3\lib\site-packages\torch\_tensor.py in __iter__(self)
#     914         # See gh-54457
#     915         if self.dim() == 0:
# --> 916             raise TypeError("iteration over a 0-d tensor")
#     917         if torch._C._get_tracing_state():
#     918             warnings.warn(
#
# TypeError: iteration over a 0-d tensor

# %%
doc=nlp(doct)
for entity in doc.ents:
    print(entity.label, '|', entity.text)

# %%
stop_words=list(STOP_WORDS)

processed_tokens=[token.lemma for token in doc if  token.text not in stop_words]

for token in doc:
    print(token ,'|',token.lemma_)

# %%
process

# %%
entities
processed_tokens
test

# %% [markdown]
# # HPO mapping

# %%
import requests
import json
from bs4 import BeautifulSoup as bs

# %%
#url=https://hpo.jax.org/api/

# here need to list all the terms and loop through them in order to retrieve the HPO terms:
#example term for testing
clinical_term = 'Loss of developmental milestones'


# Construct the API URL
url = f'https://hpo.jax.org/api/hpo/search?q={clinical_term}&category=terms'

# Send the API request
response = requests.get(url)

# checking connection
##display(response)

# Parse the response JSON
response_data = json.loads(response.text)

# %%
response_data['terms'][0]
# Extract the HPO term ID and name from the response

# %%
hpo_id = response_data['terms'][0]['name']
hpo_name = response_data['terms'][0]['id']

# Print the results
print(f"HPO ID: {hpo_id}")
print(f"HPO Name: {hpo_name}")
